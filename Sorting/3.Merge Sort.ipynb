# %% [markdown]
# # Merge Sort

# %%
from IPython.display import Image

# %%
Image('Merge-Sort-Tutorial.png')

# %%
Image('1.jpg')

# %%
Image('2.jpg')

# %%
Image('3.jpg')

# %%
Image('4.jpg')

# %%
Image('5.jpg')

# %%
Image('6.jpg')

# %%
def mergesort(arr):
    if len(arr)>1:
        mid = len(arr)//2
        L = arr[:mid]
        R = arr[mid:]
        mergesort(L)
        mergesort(R)
        
        i = j= k = 0
        
        while i <len(L) and j<len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i+=1
            else:
                arr[k] = R[j]
                j+=1
            k+=1
        
        while i<len(L):
            arr[k] = L[i]
            i+=1
            k+=1
        
        while j<len(R):
            arr[k] = R[j]
            j+=1
            k+=1
            
def printarray(arr):
    for i in range(len(arr)):
        print(arr[i],end = " ")
    print()

# %%
arr = [12,32,44,22,43,90,10]
print("Given array")
mergesort(arr)
printarray(arr)
# Out:
# Given array
# 10 12 22 32 43 44 90
